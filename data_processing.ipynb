# %%
import pandas as pd
a=pd.read_csv('eBayLaps.csv')
a
# Out:
#                                                   name  \
# 0    ~WINDOWS 11 PRO~ 14” DELL LAPTOP PC : Intel i5...
# 1    4K 15.6'' Notebook Intel Celeron N-95 16GB+512...
# 2    NEW LISTING13.3" Dell Latitude 5340 2-in-1 Int...
# 3    Dell Vostro 13 5301 13.3" FHD i7-1165G7 8GB 51...
# 4    NEW LISTINGLenovo ThinkPad E16 Gen 2, Core Ult...
# ..                                                 ...
# 256  Lenovo ThinkPad P14s Gen2 14.0" FHD i5-1145G7 ...
# 257  Lenovo Yoga 9 14ITL5: i7-41.8oz7 Fhd-Touch 2TB...
# 258  OEM Dell Latitude E7440 14" Core i5 8GB Ram La...
# 259  Fast HP EliteBook 840 G5 Laptops Sleek Thin & ...
# 260  HP EliteBook 840 G7 256GB SSD Intel i5-10310U ...
#
#                       price                                                url
# 0                   $269.99  https://www.ebay.com/itm/116223805054?_skw=lap...
# 1                   $279.20  https://www.ebay.com/itm/374837786970?_skw=lap...
# ...

# %%
b=pd.read_csv('AmazoneLaps.csv')
b
# Out:
#                                                   name      price  \
# 0    HP Newest 255 G10 Laptop for Home or Work, 16G...    $449.99
# 1    Dell Inspiron 15 3000 3520 Business Laptop Com...    $434.00
# 2    Acer Aspire 5 Slim Laptop, 15.6 inches Full HD...    $275.99
# 3    HP EliteBook 845 Business Laptop (14" FHD, AMD...        NaN
# 4    HP Chromebook 14 Laptop, Intel Celeron N4120, ...    $140.00
# ..                                                 ...        ...
# 269  ASUS ROG Strix G17 Gaming Laptop, 17.3" 300Hz ...  $5,999.00
# 270  Dell Latitude E5470 Laptop i7-6820HQ 16GB 512G...        NaN
# 271  MSI Katana GF66 15.6" FHD 240Hz Gaming Laptop,...  $1,769.00
# 272  Lenovo - IdeaPad L340 15 Gaming Laptop - Intel...    $519.99
# 273  Apple 2020 MacBook Air Laptop M1 Chip, 13" Ret...        NaN
#
#                                                    url
# 0    https://www.amazon.com/HP-255-i5-1135G7-Ethern...
# 1    https://www.amazon.com/Dell-Laptop-Touchscreen...
# ...

# %%
c=pd.read_csv('AliexpressLaps.csv')
c
# Out:
#                                                   name          price  \
# 0    CHUWI GemiBook XPro Laptop 14.1-inch Intel N10...   грн.9,133.79
# 1    15.6 Inch Ultrabook Laptops AMD Ryzen R7 4700U...  грн.17,482.22
# 2    Cheap New GPD MicroPC Micro PC 8GB RAM 256GB S...  грн.20,354.27
# 3    Yepo New Global Edition Laptop Intel Core i7 W...  грн.26,206.87
# 4    Adreamer Laptop 8GB RAM 1TB SSD Computer 13.3-...   грн.7,372.86
# ..                                                 ...            ...
# 295  Cheap Gaming Laptops I7 Win11 Computer PC Note...  грн.22,104.61
# 296  OnexPlayer Onexfly AMD Ryzen 7 8840U Laptop PC...  грн.33,364.06
# 297  2024 New HONOR Laptop MagicBook X16 Pro 2024 1...   грн.26,597.8
# 298  2024 HUAWEI MateBook GT 14 Laptop Ultra 9-185H...  грн.73,465.98
# 299  OneXPlayer X1 Intel Core Ultra 7 155H 3 IN 1 L...  грн.49,960.88
#
#                                                    url
# 0    https://www.aliexpress.com/item/10050060835602...
# ...

# %%
import pandas as pd
l=pd.read_csv('laps.csv')
l
# Out:
#                                                   name          price  \
# 0    ACEMAGIC 15.6" FHD Laptop Intel 12th N-95 16GB...        $259.99
# 1    ACEMAGIC 15.6" FHD Laptop Intel 12th Alder Lak...        $279.18
# 2    Gaming laptop HP OMEN 16" i7 13620H 16GB RAM 1...        $949.88
# 3    Fast HP EliteBook 840 G5 Laptops Sleek Thin & ...        $240.00
# 4    Lenovo ThinkPad E16 Gen 1 21JN005AUS, i7-1355U...        $749.99
# ..                                                 ...            ...
# 860  Lenovo Laptop IdeaPad 15s Thin & Light 15-inch...  грн.18,736.51
# 861  Xiaomi RedmiBook Laptop Pro15 Ryzen AMD R7-680...  грн.30,698.78
# 862  OneXplayer X1 mini AMD R7-8840U 8.8'' 3-In-1Ha...  грн.47,419.33
# 863  Xiaomi Redmi Book 14 Laptop 2024 Intel Core i7...  грн.32,568.89
# 864  2023 HUAWEI MateBook D16 Laptop i9-13900H/ i7-...  грн.43,465.29
#
#                                                    url
# 0    https://www.ebay.com/itm/285985166490?_skw=lap...
# ...
